# %% [markdown]
# <a href="https://colab.research.google.com/github/SARA3SAEED/ML-Mu/blob/main/s06c_supervised_regression_pr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supervised Learning | Regression (Polynomial Regression)

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ==========

# %% [markdown]
# ## Polynomial Linear Regresssion | Case-study (Manufacturing)

# %% [markdown]
# Scikit-Learn Polynomial Class: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html#sklearn.preprocessing.PolynomialFeatures

# %% [markdown]
# ### Importing & Creating Dataset

# %%
manufacturing = pd.read_csv('/content/drive/MyDrive/ML-Mu/s06-supervised-regression/datasets/manufacturing.csv')
manufacturing
# Out:
#      Number of Units  Manufacturing Cost
# 0           1.000000           95.066056
# 1           1.185994           96.531750
# 2           1.191499           73.661311
# 3           1.204771           95.566843
# 4           1.298773           98.777013
# ..               ...                 ...
# 995         8.099710           23.855067
# 996         8.739752           27.536542
# 997         8.780888           25.973787
# 998         8.897700           25.138311
# 999        10.000000           21.547777
#
# [1000 rows x 2 columns]

# %%
manufacturing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Number of Units     1000 non-null   float64
#  1   Manufacturing Cost  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
manufacturing.describe().round(2)
# Out:
#        Number of Units  Manufacturing Cost
# count          1000.00             1000.00
# mean              4.47               40.05
# std               1.34               10.60
# min               1.00               20.00
# 25%               3.59               32.91
# 50%               4.44               38.35
# 75%               5.32               44.53
# max              10.00              100.00

# %% [markdown]
# ### Exploring Data

# %%
sns.jointplot(x='Number of Units', y='Manufacturing Cost', data = manufacturing)

# %%
# Linear Model
sns.lmplot(x='Number of Units', y='Manufacturing Cost', data=manufacturing)

# %% [markdown]
# ### Splitting Data

# %%
X = manufacturing[['Number of Units']]

# %%
y = manufacturing['Manufacturing Cost']

# %% [markdown]
# ### Model Training & Building

# %% [markdown]
# ##### 1] Linear Model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression(fit_intercept =True)

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-6.0333683])

# %%
reg.intercept_
# Out:
# 67.03904193389238

# %% [markdown]
# ##### Visualizing Results

# %%
sns.scatterplot(data=manufacturing, x='Number of Units', y='Manufacturing Cost')
plt.plot(X, reg.predict(X), c = 'r')
plt.ylabel('Cost Per Unit Sold')
plt.xlabel('Number of Units')
plt.title('Unit Cost vs. Number of Units')
# Out:
# Text(0.5, 1.0, 'Unit Cost vs. Number of Units')

# %% [markdown]
# ##### 2] Polynomial Model

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=4)

# %%
X_poly = poly.fit_transform(X)

# %%
reg_poly = LinearRegression()

# %%
reg_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
reg_poly.coef_
# Out:
# array([ 0.00000000e+00, -5.43308190e+01,  1.22452385e+01, -1.29910949e+00,
#         5.12914120e-02])

# %%
reg_poly.intercept_
# Out:
# 131.7171595360239

# %% [markdown]
# ##### Visualizing Results

# %%
sns.scatterplot(data=manufacturing, x='Number of Units', y='Manufacturing Cost')
plt.plot(X, reg_poly.predict(X_poly), c = 'r')
plt.ylabel('Cost Per Unit Sold')
plt.xlabel('Number of Units')
plt.title('Unit Cost vs. Number of Units')
# Out:
# Text(0.5, 1.0, 'Unit Cost vs. Number of Units')

# %% [markdown]
# ==========

# %% [markdown]
# # THANK YOU!
